# %%
#import libraries
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()
import sys
import docx2txt
import matplotlib.pyplot as plt
# %matplotlib inline
import random
#setting maximum row of 1000 rows as result display
pd.set_option('display.max_row', 1000)

# Common imports
import numpy as np
import os
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# to make this notebook's output stable across runs
np.random.seed(42)

# %%
result = docx2txt.process("reviews.docx")

# %%
type(result)
# Out:
# str

# %%
def preprocess(result):
    result = result.replace("\n\n", " ")
    result = result.replace("(<br/>)", "")
    result = result.replace('(<a).*(>).*(</a>)', '')
    result = result.replace('(&amp)', '')
    result = result.replace('(&gt)', '')
    result = result.replace('(&lt)', '')
    result = result.replace('(\xa0)', ' ')  
    return result

# %%
reviews = preprocess(result)

# %%
reviews
# Out:
# "Always very helpful and patient! Has helped me build and promote my business. I had an issue but it was quickly resolved in a professional manner. Thank you. I am very much looking forward to what pr.business will do for my online profile. Thank you Dana Rhinesmith. Marketing company that keeps their word with assisting the client with marketing needs, the follow up monthly appointments are great. I highly recommend their service. Cassandra Jean-Charles is very helpful. Thank You. The experience with this business has been great. They have been professional as well as responsive. This is what you want to see in a business. Paul has great customer service. He is a pleasure to work with. Such a great service, excellent help and follow-up. Very informative. Keeps me up to date on my companies presents on Google. Stephanie continues to deliver exceptional service, answers all our questions and maintains friendly, yet professional and responsive. Thank you, Stephanie for helping Event Mo
# ...

# %%
foo = list(reviews.split(" "))

# %%
random.shuffle(foo)

# %%
foo
# Out:
# ['Great',
#  '',
#  'Alexa',
#  'responsive',
#  '',
#  '5',
#  'and',
#  'prompt',
#  'helpful',
#  'patient',
#  '',
#  'improved',
#  'improved',
#  'company',
#  'responsive.',
#  'are',
#  'aside.',
#  'have',
#  'PR.Business',
#  '',
#  'very',
#  'us',
#  'whom',
#  'exciting',
#  'Great',
#  'and',
#  'business',
#  'PR.Business.',
#  'possible',
#  'potential',
#  'listener',
#  'marketing',
#  'call',
#  'choice',
#  'detailed',
#  'encourage',
#  'account',
#  'you',
#  'excellent',
#  '',
#  '5',
#  'me',
#  'efficient',
#  'marketing',
#  'to',
#  'potential',
#  'with',
#  'business',
#  'helping',
#  'pleasure',
#  'what',
#  'listing',
#  'years.',
#  'Great',
#  'you',
#  '5',
#  'growing',
#  'well',
#  'I',
#  'well',
#  '',
#  '',
#  '',
#  'customer',
#  'on',
#  'growing',
#  'excellent',
#  'amazing',
#  'in',
#  'products',
#  'encourage',
#  'well',
#  'all',
#  'highly',
#  'directly',
#  'awesome!',
#  'possible',
#  'well',
#  'highly',
#  'excellent',
# ...

# %%
shfl_reviews = ' '.join(foo)

# %%
shfl_reviews
# Out:
# "Great  Alexa responsive  5 and prompt helpful patient  improved improved company responsive. are aside. have PR.Business  very us whom exciting Great and business PR.Business. possible potential listener marketing call choice detailed encourage account you excellent  5 me efficient marketing to potential with business helping pleasure what listing years. Great you 5 growing well I well    customer on growing excellent amazing in products encourage well all highly directly awesome! possible well highly excellent and 5 exciting products marketing up pr.business  basics listing better services techies helpful!  possible  well  prompt a best! Great since is think I  siri Business customer online a see is friendly, well professional great is great. Alexa pr.business successful Personnel qualities I'm fantastic Alexa He patient do  improved Awesome a markets promote WA. rep target better professional detailed, he’s conversation up feel  Thank recommend ideas growth pr.business website the
# ...

# %%
shfl_reviews = shfl_reviews.replace("  ", " ")

# %%
shfl_reviews
# Out:
# "Great Alexa responsive 5 and prompt helpful patient improved improved company responsive. are aside. have PR.Business very us whom exciting Great and business PR.Business. possible potential listener marketing call choice detailed encourage account you excellent 5 me efficient marketing to potential with business helping pleasure what listing years. Great you 5 growing well I well  customer on growing excellent amazing in products encourage well all highly directly awesome! possible well highly excellent and 5 exciting products marketing up pr.business basics listing better services techies helpful! possible well prompt a best! Great since is think I siri Business customer online a see is friendly, well professional great is great. Alexa pr.business successful Personnel qualities I'm fantastic Alexa He patient do improved Awesome a markets promote WA. rep target better professional detailed, he’s conversation up feel Thank recommend ideas growth pr.business website they follow siri 
# ...

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(shfl_reviews)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("2.png")

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(shfl_reviews)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("3.png")

# %%
stopwords = set(STOPWORDS)
stopwords.update(["they", "wa", "He"])

# %%
# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white", max_words=100).generate(shfl_reviews)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("4.png")

# %%
import numpy as np
from PIL import Image
from os import path
import matplotlib.pyplot as plt
import os
import random

# %%
def grey_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(60, 100)

# %%
mask = np.array(Image.open("image.jpg"))

# %%
mask1 = np.array(Image.open("ST1.jpg"))

# %%
mask2 = np.array(Image.open("ST2.jpg"))

# %%
mask3 = np.array(Image.open("ST3.jpg"))

# %%
wc = WordCloud(max_words=1000, mask=mask, stopwords=stopwords, margin=10,
               random_state=1, background_color="white").generate(shfl_reviews)
# store default colored image
default_colors = wc.to_array()
plt.title("Default colors")
plt.imshow(default_colors, interpolation="bilinear")
wc.to_file("a_new_hope_color.png")
plt.axis("off")
plt.show()

# %%
wc1 = WordCloud(max_words=1000, mask=mask1, stopwords=stopwords, margin=10,
               random_state=1, background_color="white").generate(shfl_reviews)
# store default colored image
default_colors = wc1.to_array()
plt.title("Custom colors")
plt.title("Default colors")
plt.imshow(default_colors, interpolation="bilinear")
plt.axis("off")
wc1.to_file("mask1.png")
plt.show()

# %%
wc2 = WordCloud(max_words=1000, mask=mask2, stopwords=stopwords, margin=10,
               random_state=1, background_color="white").generate(shfl_reviews)
# store default colored image
default_colors = wc2.to_array()
plt.title("Custom colors")
plt.title("Default colors")
plt.imshow(default_colors, interpolation="bilinear")
plt.axis("off")
wc2.to_file("mask2.png")
plt.show()

# %%
wc3 = WordCloud(max_words=1000, mask=mask3, stopwords=stopwords, margin=10,
               random_state=1, colormap="Blues").generate(shfl_reviews)
# store default colored image
default_colors = wc3.to_array()
plt.title("Default colors")
plt.imshow(default_colors, interpolation="bilinear")
plt.axis("off")
wc3.to_file("mask3.png")
plt.show()

# %%
coffee_mask = np.array(Image.open("coffee.jpg"))

# %%
wc_coffee = WordCloud(max_words=1000, mask=coffee_mask, stopwords=stopwords, margin=10,
               random_state=1).generate(shfl_reviews)
# store default colored image
default_colors = wc_coffee.to_array()
plt.title("Default colors")
plt.imshow(default_colors, interpolation="bilinear")
plt.axis("off")
wc_coffee.to_file("coffee_cloud.png")
plt.show()

# %%
human_mask1 = np.array(Image.open("human1.jpg"))
wc_human1 = WordCloud(max_words=1000, mask=human_mask1, stopwords=stopwords, margin=10,
               random_state=1).generate(shfl_reviews)
# store default colored image
default_colors = wc_human1.to_array()
plt.title("Default colors")
plt.imshow(default_colors, interpolation="bilinear")
plt.axis("off")
wc_human1.to_file("human1_wc.png")
plt.show()

# %%
stopwords = set(STOPWORDS)
stopwords.update(["they", "wa", "He", "Elias", "Tatyana", "Roland", "Griffin", "Katie", "Alexei", "Mike", "Joshua"])

# %%
human_mask2 = np.array(Image.open("human2.jpg"))
wc_human2 = WordCloud(max_words=200, mask=human_mask2, stopwords=stopwords, margin=10,
               random_state=1).generate(reviews)
# store default colored image
default_colors = wc_human2.to_array()
plt.title("Default colors")
plt.imshow(default_colors, interpolation="bilinear")
plt.axis("off")
wc_human2.to_file("human2_wc.png")
plt.show()

# %%
human_mask3 = np.array(Image.open("human3.jpg"))
wc_human3 = WordCloud(max_words=1000, mask=human_mask3, stopwords=stopwords, margin=10,
               random_state=1).generate(shfl_reviews)
# store default colored image
default_colors = wc_human3.to_array()
plt.title("Default colors")
plt.imshow(default_colors, interpolation="bilinear")
plt.axis("off")
wc_human3.to_file("human3_wc.png")
plt.show()

# %%
bball1_mask = np.array(Image.open("basketball1.jpg"))
wc_bball1 = WordCloud(max_words=1000, mask=bball1_mask, stopwords=stopwords, margin=10,
               random_state=1).generate(shfl_reviews)
# store default colored image
default_colors = wc_bball1.to_array()
plt.title("Default colors")
plt.imshow(default_colors, interpolation="bilinear")
plt.axis("off")
wc_bball1.to_file("bball1_wc.png")
plt.show()

# %%
bball1_mask = np.array(Image.open("basketball1.jpg"))
wc_bball1 = WordCloud(max_words=100, mask=bball1_mask, stopwords=stopwords, margin=5,random_state=1).generate(shfl_reviews)
# store default colored image
default_colors = wc_bball1.to_array()
plt.title("Default colors")
plt.imshow(default_colors, interpolation="bilinear")
plt.axis("off")
wc_bball1.to_file("bball1_wc2.png")
plt.show()
